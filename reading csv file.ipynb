# %%
import pandas as pd

# %%
df=pd.read_csv("C:\Downloads/data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-20e3b07c7b72> in <module>
# ----> 1 df=pd.read_csv("C:\Downloads/data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
df=pd.read_csv("C:\Downloads/data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-20e3b07c7b72> in <module>
# ----> 1 df=pd.read_csv("C:\Downloads/data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
df=pd.read_csv("C:\Downloads\data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-f91a6c54001f> in <module>
# ----> 1 df=pd.read_csv("C:\Downloads\data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
df=pd.read_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0ae0ded59538> in <module>
# ----> 1 df=pd.read_csv("data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
# ...

# %%
df=pd.read_csv("contacts.csv")

# %%
df=pd.read_csv("C:\Downloads\contacts.csv")

# %%
df.head()
# Out:
#              Name      Given Name Additional Name Family Name  Yomi Name  \
# 0   +918178119794   +918178119794             NaN         NaN        NaN
# 1   +918383074922   +918383074922             NaN         NaN        NaN
# 2  +9189209917881  +9189209917881             NaN         NaN        NaN
# 3         Aaj Tak             Aaj             NaN         Tak        NaN
# 4          Aanchu          Aanchu             NaN         NaN        NaN
#
#    Given Name Yomi  Additional Name Yomi  Family Name Yomi Name Prefix  \
# 0              NaN                   NaN               NaN         NaN
# 1              NaN                   NaN               NaN         NaN
# 2              NaN                   NaN               NaN         NaN
# 3              NaN                   NaN               NaN         NaN
# 4              NaN                   NaN               NaN         NaN
#
#    Name Suffix  ...  Phone 2 - Value  Address 1 - Type  Address 1 - Formatted  \
# ...

# %%
df=pd.read_excel("C:\Downloads\data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-f2c7ddd5b2ba> in <module>
# ----> 1 df=pd.read_excel("C:\Downloads\data.xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# ...

# %%
df=pd.read_excel("contacts.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-e8b3f627ffb0> in <module>
# ----> 1 df=pd.read_excel("contacts.xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
# ...

# %%
df=pd.read_csv("contacts.csv")

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (227, 42)

# %%
df.head
# Out:
# <bound method NDFrame.head of                Name      Given Name Additional Name Family Name  Yomi Name  \
# 0     +918178119794   +918178119794             NaN         NaN        NaN
# 1     +918383074922   +918383074922             NaN         NaN        NaN
# 2    +9189209917881  +9189209917881             NaN         NaN        NaN
# 3           Aaj Tak             Aaj             NaN         Tak        NaN
# 4            Aanchu          Aanchu             NaN         NaN        NaN
# ..              ...             ...             ...         ...        ...
# 222   Vimal Suncity           Vimal             NaN     Suncity        NaN
# 223  Vishal Lucifer          Vishal             NaN     Lucifer        NaN
# 224   Vodafone Care        Vodafone             NaN        Care        NaN
# 225           Zamin           Zamin             NaN         NaN        NaN
# 226         Zeeshan         Zeeshan             NaN         NaN        NaN
#
# ...

# %%
df.head()
# Out:
#              Name      Given Name Additional Name Family Name  Yomi Name  \
# 0   +918178119794   +918178119794             NaN         NaN        NaN
# 1   +918383074922   +918383074922             NaN         NaN        NaN
# 2  +9189209917881  +9189209917881             NaN         NaN        NaN
# 3         Aaj Tak             Aaj             NaN         Tak        NaN
# 4          Aanchu          Aanchu             NaN         NaN        NaN
#
#    Given Name Yomi  Additional Name Yomi  Family Name Yomi Name Prefix  \
# 0              NaN                   NaN               NaN         NaN
# 1              NaN                   NaN               NaN         NaN
# 2              NaN                   NaN               NaN         NaN
# 3              NaN                   NaN               NaN         NaN
# 4              NaN                   NaN               NaN         NaN
#
#    Name Suffix  ...  Phone 2 - Value  Address 1 - Type  Address 1 - Formatted  \
# ...

# %%
df.tail(
)
# Out:
#                Name Given Name Additional Name Family Name  Yomi Name  \
# 222   Vimal Suncity      Vimal             NaN     Suncity        NaN
# 223  Vishal Lucifer     Vishal             NaN     Lucifer        NaN
# 224   Vodafone Care   Vodafone             NaN        Care        NaN
# 225           Zamin      Zamin             NaN         NaN        NaN
# 226         Zeeshan    Zeeshan             NaN         NaN        NaN
#
#      Given Name Yomi  Additional Name Yomi  Family Name Yomi Name Prefix  \
# 222              NaN                   NaN               NaN         NaN
# 223              NaN                   NaN               NaN         NaN
# 224              NaN                   NaN               NaN         NaN
# 225              NaN                   NaN               NaN         NaN
# 226              NaN                   NaN               NaN         NaN
#
#      Name Suffix  ...  Phone 2 - Value  Address 1 - Type  \
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                Name      Given Name Additional Name Family Name  Yomi Name  \
# 0     +918178119794   +918178119794             NaN         NaN        NaN
# 1     +918383074922   +918383074922             NaN         NaN        NaN
# 2    +9189209917881  +9189209917881             NaN         NaN        NaN
# 3           Aaj Tak             Aaj             NaN         Tak        NaN
# 4            Aanchu          Aanchu             NaN         NaN        NaN
# ..              ...             ...             ...         ...        ...
# 222   Vimal Suncity           Vimal             NaN     Suncity        NaN
# 223  Vishal Lucifer          Vishal             NaN     Lucifer        NaN
# 224   Vodafone Care        Vodafone             NaN        Care        NaN
# 225           Zamin           Zamin             NaN         NaN        NaN
# 226         Zeeshan         Zeeshan             NaN         NaN        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Given Name', 'Additional Name', 'Family Name', 'Yomi Name',
#        'Given Name Yomi', 'Additional Name Yomi', 'Family Name Yomi',
#        'Name Prefix', 'Name Suffix', 'Initials', 'Nickname', 'Short Name',
#        'Maiden Name', 'Birthday', 'Gender', 'Location', 'Billing Information',
#        'Directory Server', 'Mileage', 'Occupation', 'Hobby', 'Sensitivity',
#        'Priority', 'Subject', 'Notes', 'Language', 'Photo', 'Group Membership',
#        'Phone 1 - Type', 'Phone 1 - Value', 'Phone 2 - Type',
#        'Phone 2 - Value', 'Address 1 - Type', 'Address 1 - Formatted',
#        'Address 1 - Street', 'Address 1 - City', 'Address 1 - PO Box',
#        'Address 1 - Region', 'Address 1 - Postal Code', 'Address 1 - Country',
#        'Address 1 - Extended Address'],
#       dtype='object')

# %%
    df['Name']
# Out:
# 0       +918178119794
# 1       +918383074922
# 2      +9189209917881
# 3             Aaj Tak
# 4              Aanchu
#             ...
# 222     Vimal Suncity
# 223    Vishal Lucifer
# 224     Vodafone Care
# 225             Zamin
# 226           Zeeshan
# Name: Name, Length: 227, dtype: object

# %%
df[['Name','Name Prefix']]
# Out:
#                Name Name Prefix
# 0     +918178119794         NaN
# 1     +918383074922         NaN
# 2    +9189209917881         NaN
# 3           Aaj Tak         NaN
# 4            Aanchu         NaN
# ..              ...         ...
# 222   Vimal Suncity         NaN
# 223  Vishal Lucifer         NaN
# 224   Vodafone Care         NaN
# 225           Zamin         NaN
# 226         Zeeshan         NaN
#
# [227 rows x 2 columns]

# %%
df.iloc[:5]
# Out:
#              Name      Given Name Additional Name Family Name  Yomi Name  \
# 0   +918178119794   +918178119794             NaN         NaN        NaN
# 1   +918383074922   +918383074922             NaN         NaN        NaN
# 2  +9189209917881  +9189209917881             NaN         NaN        NaN
# 3         Aaj Tak             Aaj             NaN         Tak        NaN
# 4          Aanchu          Aanchu             NaN         NaN        NaN
#
#    Given Name Yomi  Additional Name Yomi  Family Name Yomi Name Prefix  \
# 0              NaN                   NaN               NaN         NaN
# 1              NaN                   NaN               NaN         NaN
# 2              NaN                   NaN               NaN         NaN
# 3              NaN                   NaN               NaN         NaN
# 4              NaN                   NaN               NaN         NaN
#
#    Name Suffix  ...  Phone 2 - Value  Address 1 - Type  Address 1 - Formatted  \
# ...

# %%
df.iloc[:,:2]
# Out:
#                Name      Given Name
# 0     +918178119794   +918178119794
# 1     +918383074922   +918383074922
# 2    +9189209917881  +9189209917881
# 3           Aaj Tak             Aaj
# 4            Aanchu          Aanchu
# ..              ...             ...
# 222   Vimal Suncity           Vimal
# 223  Vishal Lucifer          Vishal
# 224   Vodafone Care        Vodafone
# 225           Zamin           Zamin
# 226         Zeeshan         Zeeshan
#
# [227 rows x 2 columns]
